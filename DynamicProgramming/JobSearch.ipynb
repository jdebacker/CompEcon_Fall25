# %% [markdown]
# # The McCall Job Search Model
#
# ## Sketch of the model
#
# * Job seekers are risk neutral, discount the future at rate $\beta$, and are infinitely lived.
#   * Utility: $U = \sum_{t=0}^{\infty} \beta^t c_t$
#   * Decision: accept or reject offer
# * Firms post wage offers drawn from a known distribution $F(w)$.
#   * Make no decisions, just post wage offers
#   * One hire a worker at wage $w$, they are employed forever at that wage
# * This is a model of *undirected search*
# * No recall -- workers cannot return to previous job offers
# * Workers receive job offers sequentially, one per model period
# * Wage offers are iid draws from $F(w)$
# * This is a partial equilibrium model
#
# ## Bellman equation
#
# The value of receiving a wage offer of $w$ is:
# $$
# v(w) = \max\left\{ \frac{w}{1 - \beta}, b + \beta \int_W v(w') dF(w') \right\}
# $$
#
# We'll solve this model for the implicit function $v(w)$ and the decision rule, when to accept of reject an offer.  This will be a cutoff rule, defined by a "reservation wage", $R$.  For $w \geq R$ the offer is accepted, for $w < R$ the offer is rejected.

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import time

# %%
# Create a grid of wages over which to evaluate v(w)
w_min, w_max = 10, 100  # min and max values
n = 100000 # number of grid points for wages
wages = np.linspace(w_min, w_max, n)  # use linearly spaced grid over the given support

# Define a vector of probabilities
# Each value is the probability of drawing the corresponding wage in
# the wages vector
# Assumption is that wages are drawn from a log normal
# distribution with mean mu and standard deviation sigma
mu = np.log(40)
sigma = 0.5
p = stats.lognorm.pdf(wages, s=sigma, scale=np.exp(mu))
p = p / p.sum() # normalize bc wage vector is bounded

# %%
# plot probability density function
plt.scatter(wages, p)
plt.title('Probability density function')
plt.xlabel('Wage')
plt.ylabel('Frequency')
plt.show()

# %%
# Set other model parameters
beta = 0.99  # discount factor
# Unemployment benefits, b
# assume replacement rate theta = 0.3
# benefits, b = theta * mean_wage
expected_wage = np.sum(wages * p)
theta = 0.3  # 30% replacement rate, on average
b = theta * expected_wage
print(f'Expected wage: {expected_wage:.2f}')
print(f'UI benefits: {b:.2f}')
# Out:
# Expected wage: 42.71
# UI benefits: 12.81

# %%
# Solve the model with value function iteration
V = np.zeros(wages.size)  # value function guess, could have better one
V_matrix = V.reshape(n, 1)  # will use this to keep track of V at each iteration
phi = np.zeros(wages.size) # policy function
v_tol = 1e-6
v_dist = 10
max_iter = 1000
iter = 0
time_start = time.time()
while (v_dist > v_tol) & (iter < max_iter):
    TV = np.empty_like(V)
    EV = np.sum(V * p)
    v_search = b + beta * EV
    v_accept = np.empty_like(wages)
    for i, w in enumerate(wages):
        v_accept[i] = w / (1 - beta)
    TV = np.maximum(v_accept, v_search)
    phi = v_accept > v_search
    v_dist = np.abs(V-TV).max()
    print("Iteration ", iter, ", and distance is ", v_dist)
    V = TV
    V_matrix = np.hstack((V_matrix, V.reshape(n, 1)))
    iter += 1
time_end = time.time()
print(f'Value function iteration took {time_end - time_start:.2f} seconds')
# Out:
# Iteration  0 , and distance is  9999.99999999999
# Iteration  1 , and distance is  3240.962109747601
# Iteration  2 , and distance is  737.8376027185996
# Iteration  3 , and distance is  460.5526736527372
# Iteration  4 , and distance is  330.246781739198
# Iteration  5 , and distance is  253.41063744391795
# Iteration  6 , and distance is  202.5799660204375
# Iteration  7 , and distance is  166.4773743035521
# Iteration  8 , and distance is  139.55908595386336
# Iteration  9 , and distance is  118.76541748771524
# Iteration  10 , and distance is  102.26394250665271
# Iteration  11 , and distance is  88.8880721934247
# Iteration  12 , and distance is  77.85889727232552
# Iteration  13 , and distance is  68.63608670185477
# Iteration  14 , and distance is  60.832845318063846
# Iteration  15 , and distance is  54.16490176264779
# Iteration  16 , and distance is  48.41860360691044
# Iteration  17 , and distance is  43.43024706436972
# Iteration  18 , and distance is  39.072275327567695
# Iteration  19 , and distance is  35.24381853831528
# Iteration  20 , and distance is  31.864060112413426
# Iteration  21 , and distance is  28.867489965094137
# Iteration  22 , and distance is  26.200445980715813
# Iteration  23 , and distance is  23.818553849575437
# Iteration  24 , and distance is  21.684803812870086
# Iteration  25 , and distance is  19.768086484921696
# Iteration  26 , and distance is  18.042065598120644
# Iteration  27 , and distance is  16.484299670160908
# Iteration  28 , and distance is  15.075551059156169
# Iteration  29 , and distance is  13.799237610169257
# Iteration  30 , and distance is  12.640993074222934
# Iteration  31 , and distance is  11.588312622372541
# Iteration  32 , and distance is  10.630264310352686
# Iteration  33 , and distance is  9.75725268266251
# Iteration  34 , and distance is  8.96082415156161
# Iteration  35 , and distance is  8.233505037806026
# Iteration  36 , and distance is  7.568667344531605
# Iteration  37 , and distance is  6.960414970334568
# Iteration  38 , and distance is  6.403488828334048
# Iteration  39 , and distance is  5.893185896808973
# Iteration  40 , and distance is  5.425290361447878
# Iteration  41 , and distance is  4.996014663800452
# Iteration  42 , and distance is  4.60194932626564
# Iteration  43 , and distance is  4.240019063986438
# Iteration  44 , and distance is  3.907445255019411
# Iteration  45 , and distance is  3.6017131291200712
# Iteration  46 , and distance is  3.3205433865668965
# Iteration  47 , and distance is  3.06186701831939
# Iteration  48 , and distance is  2.823803498601592
# Iteration  49 , and distance is  2.6046416385270277
# Iteration  50 , and distance is  2.402822394793475
# Iteration  51 , and distance is  2.216924009401737
# Iteration  52 , and distance is  2.045648645987967
# Iteration  53 , and distance is  1.8878103145125351
# Iteration  54 , and distance is  1.7423246104981445
# Iteration  55 , and distance is  1.608199072291427
# Iteration  56 , and distance is  1.4845247506236774
# Iteration  57 , and distance is  1.37046862320949
# Iteration  58 , and distance is  1.2652669582448652
# Iteration  59 , and distance is  1.168218799504757
# Iteration  60 , and distance is  1.0786807617114391
# Iteration  61 , and distance is  0.9960619105495425
# Iteration  62 , and distance is  0.9198192444091546
# Iteration  63 , and distance is  0.8494535847576117
# Iteration  64 , and distance is  0.7845058299162702
# Iteration  65 , and distance is  0.7245537926810357
# Iteration  66 , and distance is  0.6692087191804603
# Iteration  67 , and distance is  0.6181128802745661
# Iteration  68 , and distance is  0.570936847194389
# Iteration  69 , and distance is  0.527377263645576
# Iteration  70 , and distance is  0.48715447752329055
# Iteration  71 , and distance is  0.4500109715590952
# Iteration  72 , and distance is  0.4157092965888296
# Iteration  73 , and distance is  0.3840305914209239
# Iteration  74 , and distance is  0.3547730821019286
# Iteration  75 , and distance is  0.3277506453441674
# Iteration  76 , and distance is  0.3027916268720219
# Iteration  77 , and distance is  0.2797377867600517
# Iteration  78 , and distance is  0.258442967823612
# Iteration  79 , and distance is  0.23877243127390102
# Iteration  80 , and distance is  0.22060177940693393
# Iteration  81 , and distance is  0.20381632572389208
# Iteration  82 , and distance is  0.18831002930346585
# Iteration  83 , and distance is  0.1739851664260641
# Iteration  84 , and distance is  0.16075148900836211
# Iteration  85 , and distance is  0.14852565197725198
# Iteration  86 , and distance is  0.13723068457693444
# Iteration  87 , and distance is  0.12679557306910283
# Iteration  88 , and distance is  0.11715474328866549
# Iteration  89 , and distance is  0.10824762281936273
# Iteration  90 , and distance is  0.10001824196024245
# Iteration  91 , and distance is  0.09241496884078515
# Iteration  92 , and distance is  0.08539010763706756
# Iteration  93 , and distance is  0.07889959832573368
# Iteration  94 , and distance is  0.07290273934540892
# Iteration  95 , and distance is  0.0673619314266034
# Iteration  96 , and distance is  0.06224244097666087
# Iteration  97 , and distance is  0.05751220471029228
# Iteration  98 , and distance is  0.05314166886273597
# Iteration  99 , and distance is  0.04910334840405994
# Iteration  100 , and distance is  0.04537205308042758
# Iteration  101 , and distance is  0.041924375392227375
# Iteration  102 , and distance is  0.03873877522437397
# Iteration  103 , and distance is  0.03579527381225489
# Iteration  104 , and distance is  0.0330755393661093
# Iteration  105 , and distance is  0.030562451066543872
# Iteration  106 , and distance is  0.028240389957318257
# Iteration  107 , and distance is  0.026094795442077157
# Iteration  108 , and distance is  0.0241122148154318
# Iteration  109 , and distance is  0.02228029677826271
# Iteration  110 , and distance is  0.020587619828802417
# Iteration  111 , and distance is  0.019023538797227957
# Iteration  112 , and distance is  0.017578284007868206
# Iteration  113 , and distance is  0.01624282800094079
# Iteration  114 , and distance is  0.015008886840405467
# Iteration  115 , and distance is  0.013868695495148131
# Iteration  116 , and distance is  0.012815121921448736
# Iteration  117 , and distance is  0.011841585958791256
# Iteration  118 , and distance is  0.010942007332232606
# Iteration  119 , and distance is  0.010110767668265908
# Iteration  120 , and distance is  0.009342675410152879
# Iteration  121 , and distance is  0.00863296574789274
# Iteration  122 , and distance is  0.0079771747941777
# Iteration  123 , and distance is  0.007371200066700112
# Iteration  124 , and distance is  0.006811257346271304
# Iteration  125 , and distance is  0.006293849877692992
# Iteration  126 , and distance is  0.005815746531879995
# Iteration  127 , and distance is  0.005373961625082302
# Iteration  128 , and distance is  0.00496573627970065
# Iteration  129 , and distance is  0.004588521192090411
# Iteration  130 , and distance is  0.004239960711856838
# Iteration  131 , and distance is  0.003917878133506747
# Iteration  132 , and distance is  0.003620262097683735
# Iteration  133 , and distance is  0.003345254040141299
# Iteration  134 , and distance is  0.0030911365802239743
# Iteration  135 , and distance is  0.002856322788829857
# Iteration  136 , and distance is  0.0026393462931082468
# Iteration  137 , and distance is  0.002438852109662548
# Iteration  138 , and distance is  0.0022535954130944447
# Iteration  139 , and distance is  0.002082413648167858
# Iteration  140 , and distance is  0.0019242347470935783
# Iteration  141 , and distance is  0.0017780710222723428
# Iteration  142 , and distance is  0.0016430098066848586
# Iteration  143 , and distance is  0.0015182077604549704
# Iteration  144 , and distance is  0.0014028856030563475
# Iteration  145 , and distance is  0.001296323248425324
# Iteration  146 , and distance is  0.001197855306600104
# Iteration  147 , and distance is  0.0011068669300584588
# Iteration  148 , and distance is  0.001022789977469074
# Iteration  149 , and distance is  0.0009450994621147402
# Iteration  150 , and distance is  0.0008733102677069837
# Iteration  151 , and distance is  0.000806974140687089
# Iteration  152 , and distance is  0.0007456768653355539
# Iteration  153 , and distance is  0.0006890356953590526
# Iteration  154 , and distance is  0.0006366969537339173
# Iteration  155 , and distance is  0.0005883338335479493
# Iteration  156 , and distance is  0.0005436443443613825
# Iteration  157 , and distance is  0.000502349444104766
# Iteration  158 , and distance is  0.000464191279206716
# Iteration  159 , and distance is  0.0004289315857022302
# Iteration  160 , and distance is  0.00039635019948036643
# Iteration  161 , and distance is  0.0003662436729428009
# Iteration  162 , and distance is  0.00033842402262962423
# Iteration  163 , and distance is  0.00031271753505279776
# Iteration  164 , and distance is  0.0002889636971303844
# Iteration  165 , and distance is  0.0002670141875569243
# Iteration  166 , and distance is  0.0002467319482093444
# Iteration  167 , and distance is  0.00022799033740739105
# Iteration  168 , and distance is  0.0002106723259203136
# Iteration  169 , and distance is  0.00019466978210402885
# Iteration  170 , and distance is  0.00017988278250413714
# Iteration  171 , and distance is  0.00016621899249003036
# Iteration  172 , and distance is  0.0001535930978207034
# Iteration  173 , and distance is  0.0001419262571289437
# Iteration  174 , and distance is  0.0001311456226176233
# Iteration  175 , and distance is  0.00012118387803639052
# Iteration  176 , and distance is  0.0001119788239520858
# Iteration  177 , and distance is  0.00010347297848056769
# Iteration  178 , and distance is  9.561323258822085e-05
# Iteration  179 , and distance is  8.835050903144293e-05
# Iteration  180 , and distance is  8.16394576759194e-05
# Iteration  181 , and distance is  7.54381735532661e-05
# Iteration  182 , and distance is  6.970793310756562e-05
# Iteration  183 , and distance is  6.441296045522904e-05
# Iteration  184 , and distance is  5.952019000687869e-05
# Iteration  185 , and distance is  5.499907274497673e-05
# Iteration  186 , and distance is  5.0821376134990714e-05
# Iteration  187 , and distance is  4.69610140498844e-05
# Iteration  188 , and distance is  4.3393883970566094e-05
# Iteration  189 , and distance is  4.009771055279998e-05
# Iteration  190 , and distance is  3.705191193148494e-05
# Iteration  191 , and distance is  3.423747057240689e-05
# Iteration  192 , and distance is  3.1636812309443485e-05
# Iteration  193 , and distance is  2.9233699933683965e-05
# Iteration  194 , and distance is  2.7013124963559676e-05
# Iteration  195 , and distance is  2.4961223971331492e-05
# Iteration  196 , and distance is  2.306518490513554e-05
# Iteration  197 , and distance is  2.131316614395473e-05
# Iteration  198 , and distance is  1.9694231014000252e-05
# Iteration  199 , and distance is  1.8198267753177788e-05
# Iteration  200 , and distance is  1.681594039837364e-05
# Iteration  201 , and distance is  1.5538611478405073e-05
# Iteration  202 , and distance is  1.435830654372694e-05
# Iteration  203 , and distance is  1.326765868725488e-05
# Iteration  204 , and distance is  1.2259854884177912e-05
# Iteration  205 , and distance is  1.1328604159643874e-05
# Iteration  206 , and distance is  1.0468090295034926e-05
# Iteration  207 , and distance is  9.672939995652996e-06
# Iteration  208 , and distance is  8.938190148910508e-06
# Iteration  209 , and distance is  8.259249625552911e-06
# Iteration  210 , and distance is  7.631881999259349e-06
# Iteration  211 , and distance is  7.052169166854583e-06
# Iteration  212 , and distance is  6.516489520436153e-06
# Iteration  213 , and distance is  6.0215015764697455e-06
# Iteration  214 , and distance is  5.564111233979929e-06
# Iteration  215 , and distance is  5.141464498592541e-06
# Iteration  216 , and distance is  4.750922926177736e-06
# Iteration  217 , and distance is  4.390045432955958e-06
# Iteration  218 , and distance is  4.056580110045616e-06
# Iteration  219 , and distance is  3.748445124074351e-06
# Iteration  220 , and distance is  3.463715074758511e-06
# Iteration  221 , and distance is  3.200613718945533e-06
# Iteration  222 , and distance is  2.9574966902146116e-06
# Iteration  223 , and distance is  2.7328469514031895e-06
# Iteration  224 , and distance is  2.5252620616811328e-06
# Iteration  225 , and distance is  2.3334441721090116e-06
# Iteration  226 , and distance is  2.1561963876592927e-06
# Iteration  227 , and distance is  1.992413672269322e-06
# Iteration  228 , and distance is  1.8410701159154996e-06
# Iteration  229 , and distance is  1.7012253010761924e-06
# Iteration  230 , and distance is  1.571999746374786e-06
# Iteration  231 , and distance is  1.4525921869790182e-06
# Iteration  232 , and distance is  1.34225410874933e-06
# Iteration  233 , and distance is  1.2402979336911812e-06
# Iteration  234 , and distance is  1.146086106018629e-06
# Iteration  235 , and distance is  1.0590292731649242e-06
# Iteration  236 , and distance is  9.785862857825123e-07
# Value function iteration took 13.54 seconds

# %%
# plot value function at several iterations
plt.plot(wages, V_matrix[:, 0], label="Initial guess")
plt.plot(wages, V_matrix[:, 1], label="1st iteration")
plt.plot(wages, V_matrix[:, 2], label="2nd iteration")
plt.plot(wages, V_matrix[:, 3], label="3rd iteration")
plt.plot(wages, V_matrix[:, 4], label="4th iteration")
plt.plot(wages, V, label="True V")
plt.legend()
plt.title('Value function')
plt.xlabel('Wage')
plt.ylabel('$V(w)$')
# Out:
# Text(0, 0.5, '$V(w)$')

# %%
# plot policy function
plt.plot(wages, phi)
plt.title('Policy function')
plt.xlabel('Wage')
plt.ylabel('Accept (1) or Reject (0)')
# Out:
# Text(0, 0.5, 'Accept (1) or Reject (0)')

# %%
# Return reservation wage
R = wages[np.argmax(phi)]
print(f"Reservation wage is R = {R:.2f}")
# {b:.2f}')
# Out:
# Reservation wage is R = 76.43

# %%
# create a function to do the above
def McCallModel(wages, p, beta=0.99, theta=0.3, max_iter=1000, v_tol=1e-6):
    expected_wage = np.sum(wages * p)
    b = theta * expected_wage
    V = wages / (1 - beta)  # value function guess
    phi = np.zeros(wages.size)  # policy function
    v_dist = 10
    iter = 0
    while (v_dist > v_tol) & (iter < max_iter):
        EV = np.sum(V * p)
        v_search = b + beta * EV
        v_accept = np.empty_like(wages)
        for i, w in enumerate(wages):
            v_accept[i] = wages[i] / (1 - beta)
        TV = np.maximum(v_accept, v_search)
        phi = v_accept > v_search
        v_dist = np.abs(V - TV).max()
        V = TV
        iter += 1
    R = wages[np.argmax(phi)]
    return R

# %%
R = McCallModel(wages, p)
print(f"Reservation wage is R = {R:.2f}")
# Out:
# Reservation wage is R = 76.43

# %% [markdown]
# ## Speedup #1, Numba
#
# This is a pretty simple model and can be completely vectorized for fast operations in Python (Note that what's above could be further vectorized as the `v_accept` values can be computed outside the VFI loop).
#
# But to illustrate how [Numba](https://numba.pydata.org) can make your Python code run much faster, we'll leave in these inefficiencies.
#
# ### What is Numba?
#
# Before we talk about Numba, it's worth reminding our selves that Python is an *interpreted* language.  This means that the Python code you write is not directly executed by the computer.  Instead, it is first translated into an intermediate form, called *byte code*, which is then executed by the Python interpreter.  This is why Python is slow compared to compiled languages like C or Fortran.
#
# What Numba supports is "just in time" compilation of your Python code.  That is, when we use Numba, we can have the our Python code translated into machine code just before it is executed.  This can make the code run much faster.  And Numba can do this with many standard Python functions and operations, often with just the addition of few simple []"decorators"](https://realpython.com/primer-on-python-decorators/) to our code.
#
# Before we modify our code, we'll need to import Numba:

# %%
# Import numba's just in time (JIT) compiler
from numba import jit

# %% [markdown]
# ## Apply Numba's `@jit` Decorator
#
# In our functions above to solve for $v(w)$ we had two loops: (1) a `while` loop over our Bellman operator and (2) a `for` loop inside this Bellman operator:
#
# ```py
# v_accept = np.empty_like(wages)
#     for i, w in enumerate(wages):
#         v_accept[i] = w / (1 - beta)
#     return v_accept
# ```
#
# Again, note that this is not very efficient to use this loop.  We we could have vectorized this operation.  e..g,
# ```py
# v_accept = wages / (1 - beta)
# ```
#
# and we could move the calculation of `v_accept` outside the `while` loop since it doesn't depend on $v(w)$.
#
# **But let's ignore that** for now so we can show how to implement Numba and its potential speed ups.
#
# ### A note on "jitted" functions
#
# An important constraint to be aware of with Numba is that is Numba works best with basic Python (not custom classes and not with complex modules such as SciPy).  And with some things it doesn't just slow down, but doesn't work at all.  For example, we can't "JIT" the whole `McCallModel()` function since Numba isn't going to like the "if" statements (among other things).
#
# Also, note that there is some overhead the first time a "JIT-ed" function is compiled.  So efficiency gains from just in time compilation increase for functions that are called repeatedly.

# %%
# Copy same code as above, but add @jit decorator to a new function that replaces
# the loop inside the Bellman operator loop that determined the value
# of accepting wage w
@jit
def accept_values(wages, p, beta):
    v_accept = np.empty_like(wages)
    for i, w in enumerate(wages):
        v_accept[i] = w / (1 - beta)
    return v_accept


# Solve the model with value function iteration
def McCallModel_jit(wages, p, beta=0.99, theta=0.3, max_iter=1000, v_tol=1e-6):
    expected_wage = np.sum(wages * p)
    b = theta * expected_wage
    V = wages / (1 - beta)  # value function guess
    phi = np.zeros(wages.size)  # policy function
    v_dist = 10
    iter = 0
    while (v_dist > v_tol) & (iter < max_iter):
        EV = np.sum(V * p)
        v_search = b + beta * EV
        v_accept = accept_values(wages, p, beta)
        TV = np.maximum(v_accept, v_search)
        phi = v_accept > v_search
        v_dist = np.abs(V - TV).max()
        V = TV
        iter += 1
    R = wages[np.argmax(phi)]
    return R

# %%
# Test the speed of these the first implementation and that using Numba
# %timeit R1 = McCallModel(wages, p)
# %timeit R2 = McCallModel_jit(wages, p)
R1 = McCallModel(wages, p)
R2 = McCallModel_jit(wages, p)
print("Difference in reservation wages = ", R2 - R1)
# Out:
# 5.54 s ± 232 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# 108 ms ± 17.4 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
# Difference in reservation wages =  0.0

# %% [markdown]
# So in this case, Numba gives us a speed up of almost an order of magnitude!  Not bad for a simple change in our code!
#
# ## An Alternative Solution Method
#
# We write the job search problem slightly differently and in a way that leads to a more computationally efficient solution than the Bellman operator above.  To see this let $h$ denote the continuation value:
# $$
# h = b + \beta \int_W v(w) dF(w)
# $$
#
# The Bellman equation can be written as:
# $$
# v(w) = \max\left\{ \frac{w}{1 - \beta}, h \right\}
# $$
# Which means we can rewrite $h$ as:
# $$
# h = b + \beta \int_W \max\left\{ \frac{w}{1 - \beta}, h \right\} dF(w)
# $$
#
# This is a nonlinear equation in $h$, which we can solve using a contraction mapping theorem. We can start with some initial guess for $h$ and apply the Bellman operator, $T(h)$ to it:
#
# $$
# T(h) = b + \beta \int_W \max\left\{ \frac{w}{1 - \beta}, h \right\} dF(w)
# $$
#
# By applying the operator repeatedly we will converge to the fixed point.  Note that in the Bellman operator on the value function, we had vector of $v(w)$ (for each possible wage), here we just have a scalar $h$.

# %%
# Alternate solution -- solve for the reservation wage directly
def McCallModel_v2(wages, p, beta=0.99, theta=0.3, max_iter=1000, h_tol=1e-6):
    h = 0  # reservation wage guess
    h_dist = 10
    iter = 0
    avg_wage = np.sum(wages * p)
    b = theta * avg_wage
    continue_wage = wages / (1 - beta)
    while (h_dist > h_tol) & (iter < max_iter):
        h_new = b + beta * np.sum(np.maximum(continue_wage, h) * p)
        h_dist = np.abs(h_new - h).max()
        h = h_new
        iter += 1
    w_bar = (1 - beta) * h
    return w_bar

# %%
R =  McCallModel_v2(wages, p)
print(f"Reservation wage is R = {R:.2f}")
# Out:
# Reservation wage is R = 76.43

# %% [markdown]
# ## Comparative Statics
#
# We can use our model to look at some interesting comparative statics.
#
# For example:
# * How does the reservation wage change with the unemployment benefit?
# * How does time unemployed change with the unemployment benefit?

# %%
# How does reservation wage change with replacement rate?
n_theta = 100  # number of values for theta
theta_vals = np.linspace(0, 0.8, n_theta)
R_wages = np.empty_like(theta_vals)
for i, theta in enumerate(theta_vals):
    R_wages[i] = McCallModel_v2(wages, p, theta=theta)
plt.plot(theta_vals, R_wages)
plt.xlabel(r'Replacement rate, $\theta$')
plt.ylabel('Reservation wage')
plt.title('Reservation wage vs. replacement rate')
plt.show()

# %%
# To find the time searching/time unemployed, we need to
# simulate some draws from the wage distribution
T = 1_000 # number of draws in each sequence
N = 10_000 # number of sequences
wage_offers = np.random.choice(wages, T * N, p=p)
wage_offers = wage_offers.reshape(T, N)

# %%
# @jit
def wait_times(n_b, n_seq, n_draws, b_vals, r_wages, wage_offers):
    wait_times = np.empty((n_b, n_seq))
    # make draws of series of wage offers to see how long until accept
    for i, b in enumerate(b_vals):
        wait_times[i, :] = 0
        for j in range(n_draws):
            accept = False
            offer = 0
            while (not accept) & (wait_times[i, j] < n_seq):
                # find the first wage offer greater than reservation wage
                accept = wage_offers[i, j, offer] > r_wages[i]
                if accept:
                    wait_times[i, j] = wait_times[i, j] + 1
                else:
                    wait_times[i, j] += 1
                    offer += 1
            # compute average over the n_draws
        wait_times_avg = wait_times.mean(axis=1)
    return wait_times_avg

# %%
# How does time to accept change with replacement rate?
stop_times = np.empty_like(theta_vals)
for i, theta in enumerate(theta_vals):
    R = McCallModel_v2(wages, p, theta=theta)
    wait_time = np.argmax(wage_offers > R, axis=0)
    stop_times[i] = wait_time.mean()

# plot
plt.plot(theta_vals, stop_times)
plt.xlabel('Replacement rate')
plt.ylabel('Time to accept')
plt.title('Time to accept vs. replacement rate')
plt.show()

# %%
# How does reservation wage change with wage distribution, variance?
n_sigma = 100  # number of values for theta
sigma_vals = np.linspace(0.1, 1.5, n_sigma)
R_wages = np.empty_like(sigma_vals)
for i, sigma in enumerate(sigma_vals):
    p_sigma = stats.lognorm.pdf(wages, s=sigma, scale=np.exp(mu))
    p_sigma = p_sigma / p_sigma.sum() # normalize bc wage vector is bounded
    R_wages[i] = McCallModel_v2(wages, p_sigma)
plt.plot(sigma_vals, R_wages)
plt.xlabel(r'Variance in wages, $\sigma$')
plt.ylabel('Reservation wage')
plt.title('Reservation wage vs. variance in wages')
plt.show()

# %%
# How does time to accept change with wage distribution, variance?
stop_times = np.empty_like(sigma_vals)
T = 1_000 # number of draws in each sequence
N = 10_000 # number of sequences
for i, sigma in enumerate(sigma_vals):
    p_sigma = stats.lognorm.pdf(wages, s=sigma, scale=np.exp(mu))
    p_sigma = p_sigma / p_sigma.sum() # normalize bc wage vector is bounded
    wage_offers = np.random.choice(wages, T * N, p=p_sigma)
    wage_offers = wage_offers.reshape(T, N)
    R = McCallModel_v2(wages, p_sigma)
    wait_time = np.argmax(wage_offers > R, axis=0)
    stop_times[i] = wait_time.mean()

# plot
plt.plot(sigma_vals, stop_times)
plt.xlabel(r'Variance in wages, $\sigma$')
plt.ylabel('Time to accept')
plt.title('Time to accept vs. variance in wages')
plt.show()

# %%
# How does reservation wage change with wage distribution, mean?
# How does reservation wage change with wage distribution, variance?
n_mu = 100  # number of values for theta
mu_vals = np.linspace(0.1, 1.5, n_mu)
R_wages = np.empty_like(mu_vals)
for i, mu in enumerate(mu_vals):
    p_mu = stats.lognorm.pdf(wages, s=sigma, scale=np.exp(mu))
    p_mu = p_mu / p_mu.sum() # normalize bc wage vector is bounded
    R_wages[i] = McCallModel_v2(wages, p_mu)
plt.plot(mu_vals, R_wages)
plt.xlabel(r'Mean of wage distribution, $\mu$')
plt.ylabel('Reservation wage')
plt.title('Reservation wage vs. mean of wage distribution')
plt.show()

# %%
# How does time to accept change with wage distribution, mean?
stop_times = np.empty_like(sigma_vals)
T = 1_000 # number of draws in each sequence
N = 10_000 # number of sequences
R_wages = np.empty_like(mu_vals)
for i, mu in enumerate(mu_vals):
    p_mu = stats.lognorm.pdf(wages, s=sigma, scale=np.exp(mu))
    p_mu = p_mu / p_mu.sum() # normalize bc wage vector is bounded
    wage_offers = np.random.choice(wages, T * N, p=p_mu)
    wage_offers = wage_offers.reshape(T, N)
    R = McCallModel_v2(wages, p_mu)
    wait_time = np.argmax(wage_offers > R, axis=0)
    stop_times[i] = wait_time.mean()

# plot
plt.plot(mu_vals, R_wages)
plt.xlabel(r'Mean of wage distribution, $\mu$')
plt.ylabel('Time to accept')
plt.title('Time to accept vs. mean of wage distribution')
plt.show()
